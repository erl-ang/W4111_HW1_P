# %%
# Hello World
## Erin Liang
## uni: ell2147

# %%
print('Hello world.')
# Out:
# Hello world.

# %%
import sys

print("Python version information:", sys.version_info, "\n")
if sys.version_info.major != 3 or \
    ((sys.version_info.major == 3) and (sys.version_info.minor < 5)):
    print("You have an invalid version of Python.")
else:
    print("Your Python version is OK.")
# Out:
# Python version information: sys.version_info(major=3, minor=7, micro=6, releaselevel='final', serial=0)
#
# Your Python version is OK.

# %%
python_found = False
anaconda_found = False

for p in sys.path:
    print(p)
    if "anaconda3" in p:
        print("Found anaconda3")
        anaconda_found = True
    if "python" in p:
        print("Found some kind of Python.")
        if not anaconda_found:
            print("Found some type of Python other than Anaconda.")
            print("Test fails")
        else:
            print("OK. Path is good.")
            python_found = True
        break
    
if python_found and anaconda_found:
    print("\nPassed all path tests.")
else:
    print("\nFailed path tests.")
# Out:
# /Users/erinliang/W4111
# /Users/erinliang/opt/anaconda3/lib/python37.zip
# Found anaconda3
# Found some kind of Python.
# OK. Path is good.
#
# Passed all path tests.

# %%
import conda

# %%
conda_version_info =  conda.sys.version_info
print("Your conda version info is\n", conda_version_info)

print("Conda version information:", conda_version_info, "\n")
if conda_version_info.major != 3 or \
    ((conda_version_info.major == 3) and (conda_version_info.minor < 6)):
    print("You have an invalid version of Conda.")
else:
    print("Your Conda version is OK.")
# Out:
# Your conda version info is
#  sys.version_info(major=3, minor=7, micro=6, releaselevel='final', serial=0)
# Conda version information: sys.version_info(major=3, minor=7, micro=6, releaselevel='final', serial=0)
#
# Your Conda version is OK.

# %%
import pandas

p_version = pandas.__version__
p_nums = p_version.split(".")

print("Your pandas version is ", p_version)
# modified code from 25 to 1 to pass test (had to update)
if p_nums[1] != '1':
    print("Your version is invalid.")
else:
    print("Your version is OK.")
# Out:
# Your pandas version is  1.1.1
# Your version is OK.

# %%
print("Professor Ferguson gave us code that accesses a module's property of the form __X__")
ans = input("Answer y or n:")

if ans == 'y' or ans == 'Y':
    print("You failed the test. Prof. Ferguson is too good a programmer to ever do that.")
    print("Reformatting harddrive as punishment.")
elif ans == 'n' or ans == 'N':
    print("You passed the test.")
else:
    print("Really. Answering y or n was too tricky?")
# Out:
# Professor Ferguson gave us code that accesses a module's property of the form __X__
# Answer y or n:n
# You passed the test.

# %%
# !pip install ipython-sql

# %%
# %load_ext sql

# %%
# !pip install PyMySQL # re-ran cell, but initially was uninstalled

# %%
# %load_ext sql
# %sql mysql+pymysql://root:dbuserdbuser@localhost/w4111
# Out:
# The sql extension is already loaded. To reload it, use:
#   %reload_ext sql

# %%
# %sql select * from countries;
# Out:
#  * mysql+pymysql://root:***@localhost/w4111
# 0 rows affected.
# []

# %%
import pandas as pd

url="https://raw.githubusercontent.com/cs109/2014_data/master/countries.csv"
countries=pd.read_csv(url)
countries
# Out:
#        Country         Region
# 0      Algeria         AFRICA
# 1       Angola         AFRICA
# 2        Benin         AFRICA
# 3     Botswana         AFRICA
# 4      Burkina         AFRICA
# ..         ...            ...
# 189   Paraguay  SOUTH AMERICA
# 190       Peru  SOUTH AMERICA
# 191   Suriname  SOUTH AMERICA
# 192    Uruguay  SOUTH AMERICA
# 193  Venezuela  SOUTH AMERICA
#
# [194 rows x 2 columns]

# %%
countries.rename(columns={"Country": "name", "Region": "region"}, inplace=True)
countries
# Out:
#           name         region
# 0      Algeria         AFRICA
# 1       Angola         AFRICA
# 2        Benin         AFRICA
# 3     Botswana         AFRICA
# 4      Burkina         AFRICA
# ..         ...            ...
# 189   Paraguay  SOUTH AMERICA
# 190       Peru  SOUTH AMERICA
# 191   Suriname  SOUTH AMERICA
# 192    Uruguay  SOUTH AMERICA
# 193  Venezuela  SOUTH AMERICA
#
# [194 rows x 2 columns]

# %%
import pymysql
from sqlalchemy import create_engine
# changed username from dbuser to root
engine = create_engine('mysql+pymysql://root:dbuserdbuser@localhost/w4111')

# %%
# this statement worked if you did not get an error
countries.to_sql(name='countries', con=engine, if_exists='append', index='id');

# %%
# %sql select * from countries;
# Out:
#  * mysql+pymysql://root:***@localhost/w4111
# 194 rows affected.
# [(0, 'Algeria', 'AFRICA'),
#  (1, 'Angola', 'AFRICA'),
#  (2, 'Benin', 'AFRICA'),
#  (3, 'Botswana', 'AFRICA'),
#  (4, 'Burkina', 'AFRICA'),
#  (5, 'Burundi', 'AFRICA'),
#  (6, 'Cameroon', 'AFRICA'),
#  (7, 'Cape Verde', 'AFRICA'),
#  (8, 'Central African Republic', 'AFRICA'),
#  (9, 'Chad', 'AFRICA'),
#  (10, 'Comoros', 'AFRICA'),
#  (11, 'Congo', 'AFRICA'),
#  (12, 'Congo, Democratic Republic of', 'AFRICA'),
#  (13, 'Djibouti', 'AFRICA'),
#  (14, 'Egypt', 'AFRICA'),
#  (15, 'Equatorial Guinea', 'AFRICA'),
#  (16, 'Eritrea', 'AFRICA'),
#  (17, 'Ethiopia', 'AFRICA'),
#  (18, 'Gabon', 'AFRICA'),
#  (19, 'Gambia', 'AFRICA'),
#  (20, 'Ghana', 'AFRICA'),
#  (21, 'Guinea', 'AFRICA'),
#  (22, 'Guinea-Bissau', 'AFRICA'),
#  (23, 'Ivory Coast', 'AFRICA'),
#  (24, 'Kenya', 'AFRICA'),
#  (25, 'Lesotho', 'AFRICA'),
#  (26, 'Liberia', 'AFRICA'),
#  (27, 'Libya', 'AFRICA'),
#  (28, 'Madagascar', 'AFRICA'),
# ...

# %%
# I think that's everything!
